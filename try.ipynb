# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

dataset = pd.read_csv('student.csv')



# X = dataset['Math'].values
# y = dataset['Reading'].values
# z = dataset['Writing'].values

X = [1,2,3]
y = [11,12,13]
z = [21,22,33]


figure = plt.figure(figsize=(12,6))
ax = Axes3D(figure)
ax.bar3d(X,y,z, dx=2, dy=2, dz=2)
plt.show()

# %%
import numpy as np

# %%
a = np.arange(5)
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
import plotly 
plotly.tools.set_credentials_file(username='abhishekraj3147166', api_key='4JYqnvEcKTXFThHa7Yav')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-04b6098c58bf> in <module>()
# ----> 1 import plotly
#       2 plotly.tools.set_credentials_file(username='abhishekraj3147166', api_key='4JYqnvEcKTXFThHa7Yav')
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd

x = np.array([i for i in range(1,301)])
y = np.random.randint(1,1000,300)
z = np.random.randint(500,1000,300)

figure = plt.figure(figsize=(10,6))
axes = Axes3D(figure)
axes.scatter(x,y,z)
plt.show()
